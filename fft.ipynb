# %%
import numpy as np
import soundfile
import dsp.processing as ps

import matplotlib.pyplot as plt

# %% [markdown]
# ## Durchführung der Fast-Fourier-Transformation

# %%
data, sample_rate = soundfile.read("C:/Users/felix/Music/lavenders.wav")
mono = ps.stereo_to_mono(data)

# Sekunde 5
second = mono[sample_rate*5:sample_rate*6]

# Pre-Emphasis
import dsp.filter

# 5te Sekunde
rfft = np.fft.fft(second, n=1024)


#plt.plot(fft)
plt.plot(rfft)
# Out:
# C:\Users\felix\anaconda3\envs\AudioVisualizer\lib\site-packages\matplotlib\cbook\__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
