# %%
import numpy as np
import soundfile
import dsp.processing as ps

import matplotlib.pyplot as plt

# %% [markdown]
# ## Durchführung der Fast-Fourier-Transformation

# %%
data, sample_rate = soundfile.read("/home/felix/Musik/3.wav")
mono = ps.stereo_to_mono(data)


second = mono[sample_rate*5:sample_rate*6]

# Pre-Emphasis
import dsp.filter

# 5te Sekunde
rfft = np.fft.rfft(second, n=1024)


#plt.plot(fft)
plt.plot(rfft)
